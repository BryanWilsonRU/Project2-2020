# %%
# Dependencie
import pandas as pd
import numpy as np

# %%
# Load in file
poverty_file = "PeopleBelowPovertyLevel.csv"
# Read and display the CSV with Pandas
poverty_file_df = pd.read_csv(poverty_file)
poverty_file_df.head()
# Out:
#   Geographic Area             City poverty_rate
# 0              AL       Abanda CDP         78.8
# 1              AL   Abbeville city         29.1
# 2              AL  Adamsville city         25.5
# 3              AL     Addison town         30.7
# 4              AL       Akron town           42

# %%
poverty_file_df
# Out:
#       Geographic Area                    City poverty_rate
# 0                  AL              Abanda CDP         78.8
# 1                  AL          Abbeville city         29.1
# 2                  AL         Adamsville city         25.5
# 3                  AL            Addison town         30.7
# 4                  AL              Akron town           42
# ...               ...                     ...          ...
# 29324              WY  Woods Landing-Jelm CDP         18.6
# 29325              WY            Worland city         15.3
# 29326              WY             Wright town          5.9
# 29327              WY              Yoder town          5.4
# 29328              WY           Y-O Ranch CDP            0
#
# [29329 rows x 3 columns]

# %%
#Strip blank spaces using Lambda funcion
poverty_file_df["Geographic Area"]=poverty_file_df["Geographic Area"].apply(lambda x: x.strip())
poverty_file_df["City"]=poverty_file_df["City"].apply(lambda x: x.strip())
poverty_file_df["poverty_rate"]=poverty_file_df["poverty_rate"].apply(lambda x: x.strip())
#Display results-final df
poverty_file_df.head()
# Out:
#   Geographic Area             City poverty_rate
# 0              AL       Abanda CDP         78.8
# 1              AL   Abbeville city         29.1
# 2              AL  Adamsville city         25.5
# 3              AL     Addison town         30.7
# 4              AL       Akron town           42

# %%
S1= poverty_file_df.drop(columns ='City')

# %%
#Drop all rows
S2 = S1.dropna(how='any')
S2.head()
# Out:
#   Geographic Area poverty_rate
# 0              AL         78.8
# 1              AL         29.1
# 2              AL         25.5
# 3              AL         30.7
# 4              AL           42

# %%
#List of columns to create db
S2.dtypes
# Out:
# Geographic Area    object
# poverty_rate       object
# dtype: object

# %%
S2.count()
# Out:
# Geographic Area    29329
# poverty_rate       29329
# dtype: int64

# %%
S3 = S2[~S2.poverty_rate.str.contains("-")]
S3.count()
# Out:
# Geographic Area    29128
# poverty_rate       29128
# dtype: int64

# %%
#Rename the column name
S4 = S3.rename(columns={"Geographic Area" : "State"})
S4.head()
# Out:
#   State poverty_rate
# 0    AL         78.8
# 1    AL         29.1
# 2    AL         25.5
# 3    AL         30.7
# 4    AL           42

# %%
#List of columns to create db
S4.dtypes
# Out:
# State           object
# poverty_rate    object
# dtype: object

# %%
S4[["poverty_rate"]] = S4[["poverty_rate"]].apply(pd.to_numeric)
S4.dtypes
# Out:
# State            object
# poverty_rate    float64
# dtype: object

# %%
S5 = S4.groupby('State').poverty_rate.mean()
S5.head()
# Out:
# State
# AK    19.852994
# AL    20.647089
# AR    22.963216
# AZ    25.666441
# CA    17.124650
# Name: poverty_rate, dtype: float64

# %%
cleaned_Poverty_file= S5.to_frame()
cleaned_Poverty_file.head()
# Out:
#        poverty_rate
# State
# AK        19.852994
# AL        20.647089
# AR        22.963216
# AZ        25.666441
# CA        17.124650

# %%
cleaning_Done = cleaned_Poverty_file.rename(columns={"poverty_rate" : "poverty_rate in (%)"})
cleaning_Done
# Out:
#        poverty_rate in (%)
# State
# AK               19.852994
# AL               20.647089
# AR               22.963216
# AZ               25.666441
# CA               17.124650
# CO               13.362832
# CT                9.137500
# DC               18.000000
# DE               12.555844
# FL               17.566011
# GA               23.777404
# HI               13.400662
# IA               12.292522
# ID               18.236889
# IL               13.879780
# IN               15.499853
# KS               14.762985
# KY               20.080000
# LA               22.338901
# MA                9.585306
# MD               10.312209
# ME               16.893846
# MI               17.900723
# MN               13.745736
# MO               20.105859
# MS               26.884254
# MT               16.513774
# NC               19.747290
# ND               12.162250
# NE               12.984575
# NH               12.659794
# NJ                8.190976
# NM               23.080787
# ...

# %%
cleaning_Done.to_csv(r'/Users/hasti/Desktop/Poverty_rate.csv')
