# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Project2_Data/PoliceKillingsUS.csv", engine='python')
df
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  2/1/2015              shot         gun  53.0
# 1        4    Lewis Lee Lembke  2/1/2015              shot         gun  47.0
# 2        5  John Paul Quintero  3/1/2015  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  4/1/2015              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  4/1/2015              shot    nail gun  39.0
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun  31.0
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun  48.0
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle  28.0
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife  32.0
#
# ...

# %%
# groupby all columns
manner_death = df.groupby("manner_of_death")
armed = df.groupby("armed")
mental_illness = df.groupby("signs_of_mental_illness")
threat = df.groupby("threat_level")
flee = df.groupby("flee")
body_cam = df.groupby("body_camera")
race = df.groupby("race")
gender = df.groupby("gender")

# %%
race.count()
# a = asian
# b = black
# h = hispanic
# n = native american
# o = other
# w = white
# Out:
#         id  name  date  manner_of_death  armed   age  gender  city  state  \
# race
# A       39    39    39               39     39    38      39    39     39
# B      618   618   618              618    614   609     618   618    618
# H      423   423   423              423    422   413     423   423    423
# N       31    31    31               31     31    31      31    31     31
# O       28    28    28               28     28    28      28    28     28
# W     1201  1201  1201             1201   1200  1192    1201  1201   1201
#
#       signs_of_mental_illness  threat_level  flee  body_camera
# race
# A                          39            39    37           39
# B                         618           618   605          618
# H                         423           423   411          423
# N                          31            31    29           31
# O                          28            28    28           28
# ...

# %%
df.count()
# Out:
# id                         2535
# name                       2535
# date                       2535
# manner_of_death            2535
# armed                      2526
# age                        2458
# gender                     2535
# race                       2340
# city                       2535
# state                      2535
# signs_of_mental_illness    2535
# threat_level               2535
# flee                       2470
# body_camera                2535
# dtype: int64

# %%
df = df.dropna(how='any')
df.count()
# Out:
# id                         2254
# name                       2254
# date                       2254
# manner_of_death            2254
# armed                      2254
# age                        2254
# gender                     2254
# race                       2254
# city                       2254
# state                      2254
# signs_of_mental_illness    2254
# threat_level               2254
# flee                       2254
# body_camera                2254
# dtype: int64

# %%
df.dtypes
# Out:
# id                           int64
# name                        object
# date                        object
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# dtype: object

# %%
armed.count()
# Out:
#                           id  name  date  manner_of_death  age  gender  race  \
# armed
# Taser                      9     9     9                9    9       9     6
# air conditioner            1     1     1                1    1       1     1
# ax                         9     9     9                9    9       9     8
# baseball bat               8     8     8                8    8       8     7
# baseball bat and bottle    1     1     1                1    1       1     1
# ...                      ...   ...   ...              ...  ...     ...   ...
# toy weapon               104   104   104              104  103     104   102
# unarmed                  171   171   171              171  170     171   170
# undetermined             117   117   117              117  112     117   101
# unknown weapon            18    18    18               18   16      18    16
# vehicle                  177   177   177              177  172     177   165
#
# ...

# %%
df
# Out:
#         id                name      date   manner_of_death         armed  \
# 0        3          Tim Elliot  2/1/2015              shot           gun
# 1        4    Lewis Lee Lembke  2/1/2015              shot           gun
# 2        5  John Paul Quintero  3/1/2015  shot and Tasered       unarmed
# 3        8     Matthew Hoffman  4/1/2015              shot    toy weapon
# 4        9   Michael Rodriguez  4/1/2015              shot      nail gun
# ...    ...                 ...       ...               ...           ...
# 2519  2805         Aries Clark  25/07/17              shot  undetermined
# 2523  2808   Kesharn K. Burney  26/07/17              shot       vehicle
# 2525  2820    Deltra Henderson  27/07/17              shot           gun
# 2533  2817       Isaiah Tucker  31/07/17              shot       vehicle
# 2534  2815        Dwayne Jeune  31/07/17              shot         knife
#
#        age gender race           city state  signs_of_mental_illness  \
# ...

# %%
gender.count()
# Out:
#           id  name  date  manner_of_death  armed   age  race  city  state  \
# gender
# F        107   107   107              107    107   104    98   107    107
# M       2428  2428  2428             2428   2419  2354  2242  2428   2428
#
#         signs_of_mental_illness  threat_level  flee  body_camera
# gender
# F                           107           107   104          107
# M                          2428          2428  2366         2428

# %%
del df['city']

# %%
del df['id']

# %%
del df['name']

# %%
df.set_index("state")
# Out:
#            date   manner_of_death         armed   age gender race  \
# state
# WA     2/1/2015              shot           gun  53.0      M    A
# OR     2/1/2015              shot           gun  47.0      M    W
# KS     3/1/2015  shot and Tasered       unarmed  23.0      M    H
# CA     4/1/2015              shot    toy weapon  32.0      M    W
# CO     4/1/2015              shot      nail gun  39.0      M    H
# ...         ...               ...           ...   ...    ...  ...
# AR     25/07/17              shot  undetermined  16.0      M    B
# OH     26/07/17              shot       vehicle  25.0      M    B
# LA     27/07/17              shot           gun  39.0      M    B
# WI     31/07/17              shot       vehicle  28.0      M    B
# NY     31/07/17              shot         knife  32.0      M    B
#
#        signs_of_mental_illness  threat_level         flee  body_camera
# state
# WA                        True        attack  Not fleeing        False
# ...

# %%
df = df.rename(columns = {"date": "Date",
                          "manner_of_death": "Manner_of_Death",
                          "armed": "Armed",
                          "age": "Age",
                          "gender": "Gender",
                          "race": "Race",
                          "state": "State",
                          "signs_of_mental_illness": "Signs_of_Mental_Illness",
                          "threat_level": "Threat_Level",
                          "flee": "Flee",
                          "body_camera": "Body_Camera"})

# %%
df
# Out:
#           Date   Manner_of_Death         Armed   Age Gender Race State  \
# 0     2/1/2015              shot           gun  53.0      M    A    WA
# 1     2/1/2015              shot           gun  47.0      M    W    OR
# 2     3/1/2015  shot and Tasered       unarmed  23.0      M    H    KS
# 3     4/1/2015              shot    toy weapon  32.0      M    W    CA
# 4     4/1/2015              shot      nail gun  39.0      M    H    CO
# ...        ...               ...           ...   ...    ...  ...   ...
# 2519  25/07/17              shot  undetermined  16.0      M    B    AR
# 2523  26/07/17              shot       vehicle  25.0      M    B    OH
# 2525  27/07/17              shot           gun  39.0      M    B    LA
# 2533  31/07/17              shot       vehicle  28.0      M    B    WI
# 2534  31/07/17              shot         knife  32.0      M    B    NY
#
#       Signs_of_Mental_Illness  Threat_Level         Flee  Body_Camera
# ...

# %%
df.to_csv("Clean_Data/police_killings.csv", header=True)
