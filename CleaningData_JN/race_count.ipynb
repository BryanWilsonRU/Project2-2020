# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../CleanData/encounter_data_new.csv")
df
# Out:
#          ID  Age  Gender                     Race              City State  \
# 0     18697   22    Male  European-American/White           Chatham    MA
# 1     18698   18    Male          Hispanic/Latino         Key Largo    FL
# 2     18699   22    Male   African-American/Black          Savannah    GA
# 3     18700   53    Male   Asian/Pacific Islander           Shelton    WA
# 4     18701   47    Male  European-American/White             Aloha    OR
# ...     ...  ...     ...                      ...               ...   ...
# 8974  28189   39    Male         Race unspecified  Manheim Township    PA
# 8975  28190   39  Female         Race unspecified            Poteau    OK
# 8976  28191   37  Female          Hispanic/Latino      Hanover Park    IL
# 8977  28192   36    Male  European-American/White            Bryant    AR
# 8978  28193   25    Male          Hispanic/Latino    Corpus Christi    TX
#
#        Latitude   Longitude                     Cause_of_Death  \
# ...

# %%
race = df["Race"].value_counts()
# Out:
# European-American/White    3879
# African-American/Black     2233
# Race unspecified           1284
# Hispanic/Latino            1274
# Asian/Pacific Islander      150
# Native American/Alaskan     135
# Middle Eastern               23
# HIspanic/Latino               1
# Name: Race, dtype: int64

# %%
race.to_csv("../CleanData/data_count/race_count.csv")
# Out:
# C:\Users\ricks\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-5-9c326ea4e5fe> in <module>
# ----> 1 race.to_csv("../CleanData/data_count/race_count.csv")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in to_csv(self, *args, **kwargs)
#    4680             )
#    4681             kwargs["header"] = False  # Backwards compatibility.
# -> 4682         return self.to_frame().to_csv(**kwargs)
#    4683
#    4684     @Appender(generic._shared_docs["isna"] % _shared_doc_kwargs)
#
# ...
